# %%
import nfflr.AtomsDataset
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import nfflr.AtomsDataset
#
# File ~/.virtualenvs/nist/lib/python3.10/site-packages/nfflr/__init__.py:9
#       5 __all__ = ["Atoms", "AtomsDataset", "CACHE"]
#       7 # nfflr: top-level API
#       8 # Atoms
# ----> 9 from .atoms import Atoms, spglib_cell, batch, unbatch, to_ase
#      11 # AtomsDataset
#      12 from .data.dataset import AtomsDataset, collate_forcefield_targets
#
# File ~/.virtualenvs/nist/lib/python3.10/site-packages/nfflr/atoms.py:8
#       5 from typing import TypeAlias, Optional, List
#       7 import ase
# ----> 8 import dgl
#       9 import torch
#      10 from plum import dispatch
#
# File ~/.virtualenvs/nist/lib/python3.10/site-packages/dgl/__init__.py:16
#      13 from .logging import enable_verbose_logging  # usort: skip
# ...
